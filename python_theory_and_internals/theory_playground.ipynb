# %%
from block_02_collections import filter_predictions

predictions = [
    ("img_001.jpg", "cat", 0.91),
    ("img_002.jpg", "dog", 0.76),
    ("img_003.jpg", "cat", 0.84),
]

filter_predictions(predictions, 0.8)
# Out:
# [('img_001.jpg', 'cat'), ('img_003.jpg', 'cat')]
